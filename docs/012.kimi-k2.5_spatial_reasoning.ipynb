# %%
# !pip install openai hcaptcha_challenger
# Out:
# Requirement already satisfied: openai in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (2.15.0)
# Requirement already satisfied: hcaptcha_challenger in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (0.19.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: google-genai>=1.56.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (1.56.0)
# Requirement already satisfied: loguru>=0.7.3 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (0.7.3)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (3.10.8)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (1.1.2)
# Requirement already satisfied: opencv-python<5.0,>=4.11.0.88 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (4.12.0.88)
# Requirement already satisfied: pillow>=11.1.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (12.1.0)
# Requirement already satisfied: playwright in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (1.57.0)
# Requirement already satisfied: pydantic-settings>=2.12.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (2.12.0)
# Requirement already satisfied: pytz>=2025.2 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (2025.2)
# Requirement already satisfied: typer>=0.21.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from hcaptcha_challenger) (0.21.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from opencv-python<5.0,>=4.11.0.88->hcaptcha_challenger) (2.2.6)
# Requirement already satisfied: google-auth<3.0.0,>=2.45.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-auth[requests]<3.0.0,>=2.45.0->google-genai>=1.56.0->hcaptcha_challenger) (2.47.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-genai>=1.56.0->hcaptcha_challenger) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-genai>=1.56.0->hcaptcha_challenger) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-genai>=1.56.0->hcaptcha_challenger) (15.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai>=1.56.0->hcaptcha_challenger) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai>=1.56.0->hcaptcha_challenger) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai>=1.56.0->hcaptcha_challenger) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai>=1.56.0->hcaptcha_challenger) (2.6.2)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai>=1.56.0->hcaptcha_challenger) (0.6.1)
# Requirement already satisfied: h2<5,>=3 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from httpx[http2]>=0.28.1->hcaptcha_challenger) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.28.1->hcaptcha_challenger) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.28.1->hcaptcha_challenger) (4.1.0)
# Requirement already satisfied: colorama>=0.3.4 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from loguru>=0.7.3->hcaptcha_challenger) (0.4.6)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from loguru>=0.7.3->hcaptcha_challenger) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from matplotlib>=3.10.8->hcaptcha_challenger) (2.9.0.post0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from pydantic-settings>=2.12.0->hcaptcha_challenger) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->hcaptcha_challenger) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from typer>=0.21.1->hcaptcha_challenger) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from typer>=0.21.1->hcaptcha_challenger) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from typer>=0.21.1->hcaptcha_challenger) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.21.1->hcaptcha_challenger) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.21.1->hcaptcha_challenger) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.21.1->hcaptcha_challenger) (0.1.2)
# Requirement already satisfied: pyee<14,>=13 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from playwright->hcaptcha_challenger) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in c:\_githubprojects\sources\hcaptcha-challenger\.venv\lib\site-packages (from playwright->hcaptcha_challenger) (3.3.0)

# %%
import base64
import json
import os
from pathlib import Path
from typing import Literal

import dotenv
from IPython.display import JSON, Image
from matplotlib import pyplot as plt
from openai import OpenAI

from hcaptcha_challenger import ChallengeTypeEnum
from hcaptcha_challenger.helper import FloatRect, create_coordinate_grid
from hcaptcha_challenger.helper.visualize_attention_points import show_answer_points
from hcaptcha_challenger.models import ImageAreaSelectChallenge
from hcaptcha_challenger.models import ImageBinaryChallenge
from hcaptcha_challenger.models import ImageDragDropChallenge
from hcaptcha_challenger.tools import SpatialPointReasoner, SpatialPathReasoner, ImageClassifier

dotenv.load_dotenv()
# Out:
# True

# %%
# Define the bounding box for coordinate alignment
DEFAULT_BBOX = FloatRect(x=0, y=0, width=501, height=431)

MODEL = "kimi-k2.5"
THINKING_TYPE: Literal["enabled", "disabled"] = "disabled"

client = OpenAI(
    base_url=os.getenv("OPENAI_BASE_URL", "https://api.moonshot.cn/v1"),
    api_key=os.getenv("MOONSHOT_API_KEY", os.getenv("OPENAI_API_KEY"))
)

# %% [markdown]
# ## Utils

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


def build_messages(
        job_prompt_: str,
        input_image_path_: Path,
        system_prompt_: str | None = None,
        enable_helper: bool = True,
) -> list:
    messages_ = []

    if system_prompt_:
        messages_.append({"role": "system", "content": system_prompt_})

    user_message_content = [
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{encode_image(input_image_path_)}"},
        }
    ]

    if enable_helper:
        grid_divisions_path_ = input_image_path_.parent.joinpath(
            f"coordinate_grid_{input_image_path_.name}"
        )
        grid_divisions_image_ = create_coordinate_grid(input_image_path_, DEFAULT_BBOX)
        plt.imsave(str(grid_divisions_path_.resolve()), grid_divisions_image_)
        user_message_content.append(
            {
                "type": "image_url",
                "image_url": {"url": f"data:image/png;base64,{encode_image(grid_divisions_path_)}"},
            }
        )

    # Create content with only the image
    # When the model performs inference, the image will also be converted into the corresponding Image Token.
    # When the context of a dialogue is long, the model may focus on the backward Prompt.
    # Therefore, when writing Prompt, you can say that the instructions are placed at the end
    # and the images are placed at the head, so that the model can pay more attention to the instructions,
    # thereby improving the effect of the instructions following.
    user_message_content.append({"type": "text", "text": job_prompt_})

    user_message = {"role": "user", "content": user_message_content}

    messages_.append(user_message)

    return messages_

# %% [markdown]
# ## Image Classifier

# %%
job_prompt = f"""
Task:
Solve the challenge, use [0,0] ~ [2,2] to locate 9grid, output the coordinates of the correct answer as JSON.

Please output your response in the following JSON format:
{json.dumps(ImageBinaryChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_label_binary_filepath = Path("assets/image_label_binary/20250817200551586876_0_challenge_view.png")
completion_image_label_binary = client.chat.completions.create(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_label_binary_filepath,
        ImageClassifier.description,
        enable_helper=False
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)
challenge_result_image_label_binary = completion_image_label_binary.choices[0].message.content

JSON(completion_image_label_binary.model_dump())

# %%
final_answer = ImageBinaryChallenge(**json.loads(completion_image_label_binary.choices[0].message.content))
print(final_answer.coordinates)
Image(image_label_binary_filepath)
# Out:
# [BoundingBoxCoordinate(box_2d=[1, 1]), BoundingBoxCoordinate(box_2d=[2, 2])]

# %% [markdown]
# ## Spatial Point Reasoning (`IMAGE_LABEL_SINGLE_SELECT`)

# %%
job_prompt = f"""
**JobType:** {ChallengeTypeEnum.IMAGE_LABEL_SINGLE_SELECT.value}

Please output your response in the following JSON format:
{json.dumps(ImageAreaSelectChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_label_area_select_filepath_1 = Path("assets/image_label_area_select/20250426225911341786_0_challenge_view.png")

completion_image_label_area_select_1 = client.chat.completions.create(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_label_area_select_filepath_1,
        SpatialPointReasoner.description,
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)

JSON(completion_image_label_area_select_1.model_dump())

# %%
# Visualize the answer on the actual image
result = show_answer_points(
    image_label_area_select_filepath_1,
    ImageAreaSelectChallenge(**json.loads(completion_image_label_area_select_1.choices[0].message.content)),
    DEFAULT_BBOX,
    show_plot=True,
)

# %% [markdown]
# ## Spatial Point Reasoning (`IMAGE_LABEL_MULTI_SELECT_`)

# %%
job_prompt = f"""
**JobType:** {ChallengeTypeEnum.IMAGE_LABEL_MULTI_SELECT.value}

Please output your response in the following JSON format:
{json.dumps(ImageAreaSelectChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_label_area_select_filepath_2 = Path("assets/image_label_area_select/20250818003234074379_0_challenge_view.png")

completion_image_label_area_select_2 = client.chat.completions.create(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_label_area_select_filepath_2,
        SpatialPointReasoner.description,
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)

JSON(completion_image_label_area_select_2.model_dump())

# %%
# Visualize the answer on the actual image
result_2 = show_answer_points(
    image_label_area_select_filepath_2,
    ImageAreaSelectChallenge(**json.loads(completion_image_label_area_select_2.choices[0].message.content)),
    DEFAULT_BBOX,
    show_plot=True,
)

# %% [markdown]
# ## Spatial Path Reasoning (`IMAGE_DRAG_SINGLE`)

# %%
job_prompt = f"""
**JobType:** {ChallengeTypeEnum.IMAGE_DRAG_SINGLE.value}

Please output your response in the following JSON format:
{json.dumps(ImageDragDropChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_drag_drop_single_single_filepath = Path("assets/image_drag_drop/20250717190455891095_0_challenge_view.png")

completion_image_drag_drop_single = client.chat.completions.parse(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_drag_drop_single_single_filepath,
        SpatialPathReasoner.description,
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)

JSON(completion_image_drag_drop_single.model_dump())

# %%
# Visualize the answer on the actual image
result = show_answer_points(
    image_drag_drop_single_single_filepath,
    ImageDragDropChallenge(**json.loads(completion_image_drag_drop_single.choices[0].message.content)),
    DEFAULT_BBOX,
    show_plot=True,
    path_color='blue',
    arrow_width=3,
    alpha=0.7
)

# %% [markdown]
# ## Spatial Path Reasoning (`IMAGE_DRAG_MULTI`)

# %%
job_prompt = f"""
**JobType:** {ChallengeTypeEnum.IMAGE_DRAG_MULTI.value}

Please output your response in the following JSON format:
{json.dumps(ImageDragDropChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_drag_drop_single_multi_filepath = Path("assets/image_drag_drop/20250818003210373861_0_challenge_view.png")

completion_image_drag_drop_multi = client.chat.completions.parse(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_drag_drop_single_multi_filepath,
        SpatialPathReasoner.description,
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)

JSON(completion_image_drag_drop_multi.model_dump())

# %%
# Visualize the answer on the actual image
result = show_answer_points(
    image_drag_drop_single_multi_filepath,
    ImageDragDropChallenge(**json.loads(completion_image_drag_drop_multi.choices[0].message.content)),
    DEFAULT_BBOX,
    show_plot=True,
    path_color='blue',
    arrow_width=3,
    alpha=0.7
)

# %% [markdown]
# ## Spatial Path Reasoning (`IMAGE_DRAG_MULTI:CHALLENGE`)

# %%
job_prompt = f"""
**JobType:** {ChallengeTypeEnum.IMAGE_DRAG_MULTI.value}

Please output your response in the following JSON format:
{json.dumps(ImageDragDropChallenge.model_json_schema(), indent=2, ensure_ascii=False)}
"""

image_drag_drop_single_multi_filepath_2 = Path("assets/image_drag_drop/single_9.png")

completion_image_drag_drop_multi_2 = client.chat.completions.parse(
    model=MODEL,
    messages=build_messages(
        job_prompt,
        image_drag_drop_single_multi_filepath_2,
        SpatialPathReasoner.description,
    ),
    response_format={"type": "json_object"},
    extra_body={"thinking": {"type": THINKING_TYPE}}
)

JSON(completion_image_drag_drop_multi_2.model_dump())

# %%
# Visualize the answer on the actual image
result = show_answer_points(
    image_drag_drop_single_multi_filepath_2,
    ImageDragDropChallenge(**json.loads(completion_image_drag_drop_multi_2.choices[0].message.content)),
    DEFAULT_BBOX,
    show_plot=True,
    path_color='blue',
    arrow_width=3,
    alpha=0.7
)
